# %% [markdown]
# # EDA Project  :
# 1. What is EDA?
#
#
# 2. Why Exploratory Data Analysis is important?
#
#
# 3. Steps to be followed in EDA process
#
#
# 4. Project on EDA
#
#
# 5. Summary

# %% [markdown]
# ## 1. What is EDA? :
# __Exploratory Data Analysis__ (EDA) is a process of describing the data by means of statistical and visualization techniques in order to bring important aspects of that data into focus for further analysis.

# %% [markdown]
# ## 2. Why Exploratory Data Analysis is important?
#
# 1. EDA is a process of examining the available dataset to understand the structure, patterns and characteristics of the dataset.
#
#
# 2. EDA helps in identifying and addressing data quality issues such as missing values, outliers, etc. Cleaning and preprocessing of the data during the exploratory phase improves the quality and reliability of subsequent analyses.
#
#
# 3. The visual representations generated during EDA, such as charts and graphs, make it easier to communicate complex patterns and insights to stakeholders who may not have a technical background. Visualization enhances the interpretability of results.

# %% [markdown]
# ## 3. Steps to be followed in EDA process
#
# ![EDA.png](attachment:EDA.png)
#
# **Problem Definition:** If you are trying to extract useful insight from the data.First you need to define your business problem to be solved.The Problem definition works as the driving force for your Exploratory data analysis The main tasks involved in problem definition are defining the main objective of the analysis,defining the main deliverables, outlining the main roles and responsibilities,obtaining the current status of the data. Based on this point you can define your problem Definition
#
# **Data Preparation:** This step involves methods for preparing the dataset before actual analysis in this step you define your Source of data like you Extracting the Data from your Database or Online Web Scraping.define your Data Schemas,understand the main characteristics of the data,clean the dataset,delete non-relevant datasets, transform the data into meaningful dataset.
#
# **Data Analysis:** This is one of the most crucial steps that deals with descriptive
# statistics and analysis of the data. The main tasks involve summarising the data,
# finding the hidden correlation and relationships among the data, developing
# predictive models, evaluating the models, and calculating the accuracies. You can use the Some of the techniques like data summarization are summary tables, graphs,descriptive statistics, inferential statistics, correlation statistics, searching,
# grouping, and mathematical models.
#
# **Development and Results:** This step involves presenting the dataset to the target audience in the form of graphs, summary tables, maps,and diagrams.This is also an essential step as the result analysed from the dataset should be interpretable by the business stakeholders, which is one of the major goals of EDA.

# %% [markdown]
# ## 4.Project on EDA

# %% [markdown]
# ### A. Problem Definitiion :
# Titanic is one of the most infamous shipwrecks in history. On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. **This sensational tragedy shocked the international community and led to better safety regulations for ships.**
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.
#
# In this Our challenge, We Analysis This Data Give the Answer “what sorts of people were more likely to survive?” using passenger data (i.e. name, age, gender, socio-economic class, etc).

# %% [markdown]
# ### B. Data Preparation:
# ![Data_Preparation.png](attachment:Data_Preparation.png)
#
# ### 1. External data
#
# **A.Web:** Any External site
#
# **B. Files:** Docuemnt,sheet
#
# **C. 3rd Parties**
#
# ### 2. Internal data:
#
# **A. User data:** peronal data, mail,logs
#
# **B. internal documents:** contracts,notes
#
# **c. iot device :** Alexa

# %% [markdown]
# ### Dataset:
# We use the Titanic data set from Kaggle Web Sit
# **DataLink:** https://www.kaggle.com/competitions/titanic/data
#
# ![18686404_605.jpg](attachment:18686404_605.jpg)
# ### Metadata:
# ![Metadata.png](attachment:Metadata.png)
#
# ### Variable Notes
# **pclass:** A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# **age:** Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# **sibsp:** The dataset defines family relations in this way...
#
# Sibling = brother, sister, stepbrother, stepsister
#
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
#
# Parent = mother, father
#
# Child = daughter, son, stepdaughter, stepson
#
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# ### Import the Libraries

# %%
import numpy as np
import pandas as pd
# For Visualization 
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')

# %matplotlib inline

# %%
df = pd.read_csv("train (1).csv")

# %% [markdown]
# ### Give the Overview Of the Dataset.

# %%
#Check The Data Size?
df.shape
# Out:
# (891, 12)

# %%
# View your top 5 Data 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Randomaly See your Data 
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 126          127         0       3        McMahon, Mr. Martin  male   NaN
# 171          172         0       3       Rice, Master. Arthur  male   4.0
# 603          604         0       3  Torber, Mr. Ernst William  male  44.0
# 597          598         0       3        Johnson, Mr. Alfred  male  49.0
# 67            68         0       3   Crease, Mr. Ernest James  male  19.0
#
#      SibSp  Parch     Ticket     Fare Cabin Embarked
# 126      0      0     370372   7.7500   NaN        Q
# 171      4      1     382652  29.1250   NaN        Q
# 603      0      0     364511   8.0500   NaN        S
# 597      0      0       LINE   0.0000   NaN        S
# 67       0      0  S.P. 3464   8.1583   NaN        S

# %%
# View Your Last Dataset
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Show The DataTypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#By defalut You can View ony Numerical Dataset
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Now you Can See the Catergorical 
df.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
#Show me Missing Value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# __The Age,Cabin,Embarked had the Missing Value__

# %%
#Show The any duplicate Value
df.duplicated().sum()
# Out:
# 0

# %%
#Find the Corr realtion 
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ## Data Analysis:

# %% [markdown]
# ### How May Passenger Survived

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.pie(df['Survived'].value_counts(),explode=[0,0.1],autopct='%1.2f%%')
plt.title("percentag of Survived ")
# Out:
# Text(0.5, 1.0, 'percentag of Survived ')

# %% [markdown]
# **We Can See that not many Passengers Survived the acciedent**
#
# Out of 891 passengers only 342 survived i.e Only 38.4% of the total training set survived the crash. We need to dig down more to get better insights from the data and see which categories of the passengers did survive and who didn't.
#
# We will try to check the survival rate by using the different features of the dataset. Some of the features being Sex, Port Of Embarcation, Age

# %% [markdown]
# ## PClass

# %%
sns.countplot(df['Pclass'])
plt.title("PClass")
# Out:
# Text(0.5, 1.0, 'PClass')

# %% [markdown]
# **We can Observed That most of the Passenger Are belongs to 3rd Class (Lower Class)
# And Second Highest figer from 1st Class (Upper Class)**

# %%
sns.countplot(df['Pclass'],hue=df['Survived'])
plt.title("PClass Vs Survived")
# Out:
# Text(0.5, 1.0, 'PClass Vs Survived')

# %%
pd.crosstab(df.Pclass,df.Survived,margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %% [markdown]
# ### Observation:
#
# **There are total 891 passenger are out of We Can See that 549 Passenger are Died most of Passenger belonges to  3rd Class (372).Where as Total 342 Passenger are surivied and Most of them are belonges to 1 st Class**
#
# Note: we can clearly see that Passenegers Of Pclass 1 were given a very high priority while rescue.

# %% [markdown]
# ## Sex

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# **Total 891 Passenger There are 577 are male and Remaning are 314 Are Female.**

# %%
sns.countplot(df['Sex'])
plt.title("CountNumber of Passenger based on Sex")
# Out:
# Text(0.5, 1.0, 'CountNumber of Passenger based on Sex')

# %%
sns.countplot("Sex",hue="Survived",data=df)
plt.title("Sex Vs Surived")
# Out:
# Text(0.5, 1.0, 'Sex Vs Surived')

# %%
pd.crosstab(df.Sex,df.Survived,margins=True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %% [markdown]
# ### Observation:
#
# There are 342 Passenger are surivied(342) and most of them are Female(233) and male(109) Where as 549 Passengare are Died.468 male are died in titanic.
#
# __Note:__ we can clearly see that Female Passenegers were given a very high priority while rescue.

# %% [markdown]
# ## Age

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.displot(df.Age)
plt.title("Passenger Age")
# Out:
# Text(0.5, 1.0, 'Passenger Age')

# %% [markdown]
# ### Observation:
#
# __In titanic Youngest passsenger Age Was 0.4 Years And oldest Passenger Age Was 80 Year old. There Average age of Titanic Passenger is 29.6 Years__
#
# __Note:-__ In Age  Feature there are some missing value also present.

# %% [markdown]
# ## SibSp
#
# This Feature represents Wheter a person is alone or with his Family Memebers.
#
# Sibling = brother,sister,stepbrother,stepsister
#
# Spouse = husbed, wife

# %%
pd.crosstab(df.SibSp,df.Survived)
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %% [markdown]
# ### Observation:
# __The Above Data Represent that If you traveling alone then your Surivied Chance are more as compared to other and if you sibSp Value is incrsing then Your Chance  of surivival will decreasing.__
#
# __Note:__ If You SibSp Value is less than 2 then Your Surivived Chance Are higher but as you incresing the SibSp Value Then your surivived Chace Are so less.

# %% [markdown]
# ## Fare
# This Feature show How much you pay for the Ticket

# %%
print(f"Highest Fare Was {df['Fare'].max()}")
print(f"Lowest Fare Was {df['Fare'].min()}")
print(f"AVG Fare Was {df['Fare'].mean()}")
# Out:
# Highest Fare Was 512.3292
# Lowest Fare Was 0.0
# AVG Fare Was 32.204207968574636

# %% [markdown]
# ### Observation
# **Mean Some will free Ride in titanic or may they are belonges to Cro Member**

# %%
sns.displot(df.Fare)
plt.title("Distribution of Fare")
# Out:
# Text(0.5, 1.0, 'Distribution of Fare')

# %% [markdown]
# ## Embark

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
pd.crosstab(df.Embarked,df.Survived,margins=True)
# Out:
# Survived    0    1  All
# Embarked
# C          75   93  168
# Q          47   30   77
# S         427  217  644
# All       549  340  889

# %%
sns.countplot('Embarked',hue="Survived",data=df)
plt.title("Embarked vs Survived")
# Out:
# Text(0.5, 1.0, 'Embarked vs Survived')

# %%
pd.crosstab([df.Embarked,df.Survived],df.Pclass,margins=True)
# Out:
# Pclass               1    2    3  All
# Embarked Survived
# C        0          26    8   41   75
#          1          59    9   25   93
# Q        0           1    1   45   47
#          1           1    2   27   30
# S        0          53   88  286  427
#          1          74   76   67  217
# All                214  184  491  889

# %% [markdown]
# ### Observation:
# **'C' has higher Surivied Chances based other Embarked Class**

# %% [markdown]
# # 5. Summary:
#
# **1. we can clearly see that Passenegers Of Pclass 1 were given a very high priority while rescue.**
#
#
# **2. we can clearly see that Female Passenegers were given a very high priority while rescue.**
#
#
# **3. If You SibSp Value is less than 2 then Your Surivived Chance Are higher but as you incresing the SibSp Value Then your surivived Chace Are so less.**
#
#
# **4. C' has higher Surivied Chances based other Embarked Class**
